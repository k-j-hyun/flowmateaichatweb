# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # 하이퍼파라미터 튜닝

# %%
my_learning_rate = 0.0001
my_epoch = 300
my_batch_size = 256
my_patience = 20
my_class_weight = {0 : 1.0, 1 : 1.0} # 오버 샘플링으로 class 동일하게 만들었으니 가중치도 반반으로 해야..

# %% [markdown]
# # 환경설정

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler, StandardScaler, RobustScaler
import joblib
import matplotlib.pyplot as plt
plt.rc("font",family="Malgun Gothic")
plt.rcParams['axes.unicode_minus'] = False
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from imblearn.over_sampling import SMOTE #  핵심 라이브러리

# %% [markdown]
# # 데이터 체크
# - 사전 처리된 데이터 인계 : 인사평가_피쳐생성.csv
# - data 결측치 0건(전처리 완)

# %%
data = pd.read_csv("../data/인사평가_피쳐생성.csv")
data
# Out:
#       나이      출장  참여프로젝트  근속연차        월급  이직회수 업무평가  주변평가  경력  전년도교육출장횟수  ...  \
# 0     41   1~29회       3     2   8090550     8   보통     1   8          0  ...
# 1     49  30회 이상       2     2   6925500     1   좋다     4  10          3  ...
# 2     37   1~29회       2     1   2821500     6   보통     2   7          3  ...
# 3     33  30회 이상       3     1   3927150     1   보통     3   8          3  ...
# 4     27   1~29회       3     1   4681800     9   보통     4   6          3  ...
# ...   ..     ...     ...   ...       ...   ...  ...   ...  ..        ...  ...
# 1465  36  30회 이상       4     2   3470850     4   보통     3  17          3  ...
# 1466  39   1~29회       2     3  13487850     4   보통     1   9          5  ...
# 1467  27   1~29회       4     2   8291700     1   좋다     2   6          0  ...
# 1468  49  30회 이상       2     2   7276500     2   보통     4  17          3  ...
# 1469  34   1~29회       4     2   5945400     2   보통     1   6          3  ...
#
#       연봉/프로젝트비율  경력-근속연차  근속연차차이  프로젝트밀도지수  평판×근속연차   연봉×평판점수   경력/나이비율  \
# 0     2696850.0        6      -4  0.375000        2   8090550  0.195122
# 1     3462750.0        8      -8  0.500000        8  27702000  0.204082
# 2     1410750.0        6       1  0.714286        2   5643000  0.189189
# 3     1309050.0        7      -7  0.750000        3  11781450  0.242424
# 4     1560600.0        5      -1  1.000000        4  18727200  0.222222
# ...         ...      ...     ...       ...      ...       ...       ...
# 1465   867712.5       15      -3  0.411765        6  10412550  0.472222
# 1466  6743925.0        6      -4  0.777778        3  13487850  0.230769
# 1467  2072925.0        4      -4  0.666667        4  16583400  0.222222
# 1468  3638250.0       15      -7  0.294118        8  29106000  0.346939
# 1469  1486350.0        4      -2  1.166667        2   5945400  0.176471
#
#        근속/나이비율          연봉/나이  입사나이
# 0     0.048780  197330.487805    33
# 1     0.040816  141336.734694    39
# 2     0.027027   76256.756757    30
# 3     0.030303  119004.545455    25
# 4     0.037037  173400.000000    21
# ...        ...            ...   ...
# 1465  0.055556   96412.500000    19
# 1466  0.076923  345842.307692    30
# 1467  0.074074  307100.000000    21
# 1468  0.040816  148500.000000    32
# 1469  0.058824  174864.705882    28
#
# [1470 rows x 27 columns]

# %%
data.info() # 출장, 업무평가 object 타입, 결측치 0건
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   나이         1470 non-null   int64
#  1   출장         1470 non-null   object
#  2   참여프로젝트     1470 non-null   int64
#  3   근속연차       1470 non-null   int64
#  4   월급         1470 non-null   int64
#  5   이직회수       1470 non-null   int64
#  6   업무평가       1470 non-null   object
#  7   주변평가       1470 non-null   int64
#  8   경력         1470 non-null   int64
#  9   전년도교육출장횟수  1470 non-null   int64
#  10  현회사근속년수    1470 non-null   int64
#  11  출장_등급      1470 non-null   int64
#  12  이직률        1470 non-null   float64
#  13  프로젝트참여율    1470 non-null   float64
#  14  교육출장참여율    1470 non-null   float64
#  15  현직근속비율     1470 non-null   float64
#  16  연봉/경력비율    1470 non-null   float64
#  17  연봉/프로젝트비율  1470 non-null   float64
#  18  경력-근속연차    1470 non-null   int64
#  19  근속연차차이     1470 non-null   int64
#  20  프로젝트밀도지수   1470 non-null   float64
#  21  평판×근속연차    1470 non-null   int64
#  22  연봉×평판점수    1470 non-null   int64
#  23  경력/나이비율    1470 non-null   float64
#  24  근속/나이비율    1470 non-null   float64
#  25  연봉/나이      1470 non-null   float64
#  26  입사나이       1470 non-null   int64
# dtypes: float64(10), int64(15), object(2)
# memory usage: 310.2+ KB

# %%
data.select_dtypes('object').columns
# Out:
# Index(['출장', '업무평가'], dtype='object')

# %%
data.describe() # numeric 값만 체크
# Out:
#                 나이       참여프로젝트         근속연차            월급         이직회수  \
# count  1470.000000  1470.000000  1470.000000  1.470000e+03  1470.000000
# mean     36.923810     2.729932     2.063946  8.778957e+06     2.693197
# std       9.135373     0.711561     1.106940  6.355742e+06     2.498009
# min      18.000000     1.000000     1.000000  1.362150e+06     0.000000
# 25%      30.000000     2.000000     1.000000  3.929850e+06     1.000000
# 50%      36.000000     3.000000     2.000000  6.640650e+06     2.000000
# 75%      43.000000     3.000000     3.000000  1.131165e+07     4.000000
# max      60.000000     4.000000     5.000000  2.699865e+07     9.000000
#
#               주변평가           경력    전년도교육출장횟수      현회사근속년수        출장_등급  ...  \
# count  1470.000000  1470.000000  1470.000000  1470.000000  1470.000000  ...
# mean      2.712245    11.279592     2.799320     7.008163     1.086395  ...
# std       1.081209     7.780782     1.289271     6.126525     0.532170  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       2.000000     6.000000     2.000000     3.000000     1.000000  ...
# 50%       3.000000    10.000000     3.000000     5.000000     1.000000  ...
# 75%       4.000000    15.000000     3.000000     9.000000     1.000000  ...
# max       4.000000    40.000000     6.000000    40.000000     2.000000  ...
#
#           연봉/프로젝트비율      경력-근속연차       근속연차차이     프로젝트밀도지수      평판×근속연차  \
# count  1.470000e+03  1470.000000  1470.000000  1470.000000  1470.000000
# mean   3.563946e+06     9.215646    -4.944218     0.941390     5.623810
# std    3.121243e+06     6.949229     5.613088     1.255813     4.007733
# min    3.682125e+05    -1.000000   -37.000000     0.000000     1.000000
# 25%    1.539338e+06     5.000000    -7.000000     0.333333     3.000000
# 50%    2.443950e+06     7.000000    -4.000000     0.571429     4.000000
# 75%    4.540050e+06    13.000000    -1.000000     1.000000     8.000000
# max    2.696355e+07    37.000000     5.000000     9.000000    20.000000
#
#             연봉×평판점수      경력/나이비율      근속/나이비율          연봉/나이         입사나이
# count  1.470000e+03  1470.000000  1470.000000    1470.000000  1470.000000
# mean   2.398836e+07     0.288007     0.055482  230772.805763    25.644218
# std    2.131130e+07     0.153429     0.024024  137495.271680     6.875481
# min    1.620000e+06     0.000000     0.016949   48645.000000    18.000000
# 25%    9.520875e+06     0.181818     0.035714  125834.482759    20.000000
# 50%    1.656720e+07     0.264706     0.052632  190309.821429    24.000000
# 75%    3.015934e+07     0.400000     0.071429  301678.969003    30.000000
# max    1.076922e+08     0.689655     0.137931  750600.000000    56.000000
#
# [8 rows x 25 columns]

# %%
print(data.select_dtypes('object')['출장'].value_counts())
print("-"*50)
print(data.select_dtypes('object')['업무평가'].value_counts())
# Out:
# 1~29회     1043
# 30회 이상     277
# 0회         150
# Name: 출장, dtype: int64
# --------------------------------------------------
# 보통    1244
# 좋다     226
# Name: 업무평가, dtype: int64

# %% [markdown]
# # 데이터 상관계수 및 시각화

# %% [markdown]
# ## 우선 업무평가, 출장을 라벨링해 전체를 체크 필요
# - 업무평가는 0, 1 : 보통과 좋다로 분류되며 서열이 있어 일반 labeling 보다 Ordinal Labeling
# - 출장 또한 0회 / 1 ~ 29회 / 30회 이상으로 분류되며 이에 따라서 Ordinal Labeling 필요

# %%
def ordinalEncoding(row) : 
    row = row.copy()
    manager_dict = {"보통":0, "좋다":1}
    if row['출장'] == "1~29회" :
        row['출장odm'] = 1
    elif row['출장'] == "30회 이상" :
        row['출장odm'] = 2
    else :
        row['출장odm'] = 0
    row['업무평가odm'] = manager_dict.get(row['업무평가'])
    return row

ordinalEncoding(data.iloc[0]) # ok
# Out:
# 나이                      41
# 출장                   1~29회
# 참여프로젝트                   3
# 근속연차                     2
# 월급                 8090550
# 이직회수                     8
# 업무평가                    보통
# 주변평가                     1
# 경력                       8
# 전년도교육출장횟수                0
# 현회사근속년수                  6
# 출장_등급                    1
# 이직률                    1.0
# 프로젝트참여율              0.375
# 교육출장참여율                0.0
# 현직근속비율                0.75
# 연봉/경력비율         1011318.75
# 연봉/프로젝트비율        2696850.0
# 경력-근속연차                  6
# 근속연차차이                  -4
# 프로젝트밀도지수             0.375
# 평판×근속연차                  2
# 연봉×평판점수            8090550
# 경력/나이비율           0.195122
# 근속/나이비율            0.04878
# 연봉/나이        197330.487805
# 입사나이                    33
# 출장odm                    1
# 업무평가odm                  0
# Name: 0, dtype: object

# %%
data_odm = data.apply(ordinalEncoding, axis=1)
data_odm
# Out:
#       나이      출장  참여프로젝트  근속연차        월급  이직회수 업무평가  주변평가  경력  전년도교육출장횟수  ...  \
# 0     41   1~29회       3     2   8090550     8   보통     1   8          0  ...
# 1     49  30회 이상       2     2   6925500     1   좋다     4  10          3  ...
# 2     37   1~29회       2     1   2821500     6   보통     2   7          3  ...
# 3     33  30회 이상       3     1   3927150     1   보통     3   8          3  ...
# 4     27   1~29회       3     1   4681800     9   보통     4   6          3  ...
# ...   ..     ...     ...   ...       ...   ...  ...   ...  ..        ...  ...
# 1465  36  30회 이상       4     2   3470850     4   보통     3  17          3  ...
# 1466  39   1~29회       2     3  13487850     4   보통     1   9          5  ...
# 1467  27   1~29회       4     2   8291700     1   좋다     2   6          0  ...
# 1468  49  30회 이상       2     2   7276500     2   보통     4  17          3  ...
# 1469  34   1~29회       4     2   5945400     2   보통     1   6          3  ...
#
#       근속연차차이  프로젝트밀도지수  평판×근속연차   연봉×평판점수   경력/나이비율   근속/나이비율          연봉/나이  \
# 0         -4  0.375000        2   8090550  0.195122  0.048780  197330.487805
# 1         -8  0.500000        8  27702000  0.204082  0.040816  141336.734694
# 2          1  0.714286        2   5643000  0.189189  0.027027   76256.756757
# 3         -7  0.750000        3  11781450  0.242424  0.030303  119004.545455
# 4         -1  1.000000        4  18727200  0.222222  0.037037  173400.000000
# ...      ...       ...      ...       ...       ...       ...            ...
# 1465      -3  0.411765        6  10412550  0.472222  0.055556   96412.500000
# 1466      -4  0.777778        3  13487850  0.230769  0.076923  345842.307692
# 1467      -4  0.666667        4  16583400  0.222222  0.074074  307100.000000
# 1468      -7  0.294118        8  29106000  0.346939  0.040816  148500.000000
# 1469      -2  1.166667        2   5945400  0.176471  0.058824  174864.705882
#
#       입사나이  출장odm  업무평가odm
# 0       33      1        0
# 1       39      2        1
# 2       30      1        0
# 3       25      2        0
# 4       21      1        0
# ...    ...    ...      ...
# 1465    19      2        0
# 1466    30      1        0
# 1467    21      1        1
# 1468    32      2        0
# 1469    28      1        0
#
# [1470 rows x 29 columns]

# %% [markdown]
# ### 불필요 컬럼(라벨링 전 컬럼들) 제거

# %%
data = data_odm.drop(['출장','업무평가',"출장odm"], axis=1)
data
# Out:
#       나이  참여프로젝트  근속연차        월급  이직회수  주변평가  경력  전년도교육출장횟수  현회사근속년수  출장_등급  \
# 0     41       3     2   8090550     8     1   8          0        6      1
# 1     49       2     2   6925500     1     4  10          3       10      2
# 2     37       2     1   2821500     6     2   7          3        0      1
# 3     33       3     1   3927150     1     3   8          3        8      2
# 4     27       3     1   4681800     9     4   6          3        2      1
# ...   ..     ...   ...       ...   ...   ...  ..        ...      ...    ...
# 1465  36       4     2   3470850     4     3  17          3        5      2
# 1466  39       2     3  13487850     4     1   9          5        7      1
# 1467  27       4     2   8291700     1     2   6          0        6      1
# 1468  49       2     2   7276500     2     4  17          3        9      2
# 1469  34       4     2   5945400     2     1   6          3        4      1
#
#       ...  경력-근속연차  근속연차차이  프로젝트밀도지수  평판×근속연차   연봉×평판점수   경력/나이비율   근속/나이비율  \
# 0     ...        6      -4  0.375000        2   8090550  0.195122  0.048780
# 1     ...        8      -8  0.500000        8  27702000  0.204082  0.040816
# 2     ...        6       1  0.714286        2   5643000  0.189189  0.027027
# 3     ...        7      -7  0.750000        3  11781450  0.242424  0.030303
# 4     ...        5      -1  1.000000        4  18727200  0.222222  0.037037
# ...   ...      ...     ...       ...      ...       ...       ...       ...
# 1465  ...       15      -3  0.411765        6  10412550  0.472222  0.055556
# 1466  ...        6      -4  0.777778        3  13487850  0.230769  0.076923
# 1467  ...        4      -4  0.666667        4  16583400  0.222222  0.074074
# 1468  ...       15      -7  0.294118        8  29106000  0.346939  0.040816
# 1469  ...        4      -2  1.166667        2   5945400  0.176471  0.058824
#
#               연봉/나이  입사나이  업무평가odm
# 0     197330.487805    33        0
# 1     141336.734694    39        1
# 2      76256.756757    30        0
# 3     119004.545455    25        0
# 4     173400.000000    21        0
# ...             ...   ...      ...
# 1465   96412.500000    19        0
# 1466  345842.307692    30        0
# 1467  307100.000000    21        1
# 1468  148500.000000    32        0
# 1469  174864.705882    28        0
#
# [1470 rows x 26 columns]

# %%
corrs = data.corr(numeric_only=True)

# %%
mask = np.triu(np.ones_like(corrs, dtype=bool), k=1)
plt.figure(figsize=(12,10))
sns.heatmap(corrs, annot=True,mask=mask, fmt='.2f', cmap='RdBu_r', vmin=-1, vmax=1)
plt.title('Feature 간 상관계수 히트맵')
plt.show()

# %%
corrs['업무평가odm']
# Out:
# 나이           0.001904
# 참여프로젝트      -0.029071
# 근속연차        -0.021222
# 월급          -0.017120
# 이직회수        -0.014095
# 주변평가        -0.031351
# 경력           0.006744
# 전년도교육출장횟수   -0.015579
# 현회사근속년수      0.003435
# 출장_등급        0.001683
# 이직률         -0.004408
# 프로젝트참여율      0.020697
# 교육출장참여율      0.015005
# 현직근속비율       0.021166
# 연봉/경력비율     -0.012695
# 연봉/프로젝트비율    0.008813
# 경력-근속연차      0.010931
# 근속연차차이      -0.007934
# 프로젝트밀도지수     0.018527
# 평판×근속연차     -0.021645
# 연봉×평판점수     -0.017798
# 경력/나이비율      0.009810
# 근속/나이비율     -0.019072
# 연봉/나이       -0.017191
# 입사나이        -0.005102
# 업무평가odm      1.000000
# Name: 업무평가odm, dtype: float64

# %% [markdown]
# ### 상관계수는 모두 절대값 0.03 이하로, 선형회귀 형태 분석은 불가에 가까움

# %% [markdown]
# # 데이터 분리

# %%
from sklearn.model_selection import train_test_split
# train-val-test 세트 구분 : test셋에서만 smote 진행
y = data['업무평가odm']
X = data.copy().drop('업무평가odm',axis=1)

X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_tr, X_va, y_tr, y_va = train_test_split(X_tr, y_tr, test_size=0.2, stratify=y_tr, random_state=42)

scaler = MinMaxScaler()
X_tr_s = scaler.fit_transform(X_tr)
X_va_s = scaler.transform(X_va)
X_te_s = scaler.transform(X_te)

sm = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=5)
X_tr_sm, y_tr_sm = sm.fit_resample(X_tr_s, y_tr)

# %% [markdown]
# # Model설계

# %%
inputs = Input((X_tr_sm.shape[1],))
x = Dense(128, activation='relu')(inputs)
x = BatchNormalization()(x); x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x); x = Dropout(0.2)(x)
outputs = Dense(1, activation='sigmoid')(x)
model = Model(inputs, outputs)

# %% [markdown]
# # 학습설정

# %%
from tensorflow.keras.optimizers import Adam
model.compile(
    optimizer=Adam(1e-4),
    loss='binary_crossentropy',
    metrics=[AUC(name='auc_roc', curve='ROC'), AUC(name='auc_pr', curve='PR'),
             Precision(name='precision'), Recall(name='recall'), 'accuracy']
    )

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 25)]              0
#
#  dense (Dense)               (None, 128)               3328
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,417
# Trainable params: 12,033
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# # 모델 학습

# %%
es = EarlyStopping(monitor='val_loss', patience=my_patience, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-6)
mcp = ModelCheckpoint(filepath="checkpoint/{val_loss}_{precision}.h5",save_best_only=True)

history = model.fit(
    X_tr_sm, y_tr_sm.astype(np.float32),
    epochs=my_epoch,
    batch_size=my_batch_size,
    callbacks=[es, rlr, mcp],
    verbose='auto',
    validation_data=(X_va_s, y_va.astype(np.float32)),
    class_weight=my_class_weight,
)
# Out:
# Epoch 1/300
# 7/7 [==============================] - 2s 58ms/step - loss: 0.8644 - auc_roc: 0.5108 - auc_pr: 0.5061 - precision: 0.5047 - recall: 0.5447 - accuracy: 0.5050 - val_loss: 0.6182 - val_auc_roc: 0.4151 - val_auc_pr: 0.1197 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 2/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8374 - auc_roc: 0.5277 - auc_pr: 0.5087 - precision: 0.5167 - recall: 0.5459 - accuracy: 0.5176 - val_loss: 0.6303 - val_auc_roc: 0.4299 - val_auc_pr: 0.1225 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8347 - lr: 1.0000e-04
# Epoch 3/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7998 - auc_roc: 0.5466 - auc_pr: 0.5217 - precision: 0.5375 - recall: 0.5686 - accuracy: 0.5396 - val_loss: 0.6429 - val_auc_roc: 0.4261 - val_auc_pr: 0.1220 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.8051 - lr: 1.0000e-04
# Epoch 4/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.8008 - auc_roc: 0.5490 - auc_pr: 0.5224 - precision: 0.5400 - recall: 0.5774 - accuracy: 0.5428 - val_loss: 0.6549 - val_auc_roc: 0.4403 - val_auc_pr: 0.1255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_accuracy: 0.7797 - lr: 1.0000e-04
# Epoch 5/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7862 - auc_roc: 0.5573 - auc_pr: 0.5445 - precision: 0.5292 - recall: 0.5585 - accuracy: 0.5308 - val_loss: 0.6683 - val_auc_roc: 0.4458 - val_auc_pr: 0.1271 - val_precision: 0.1081 - val_recall: 0.1111 - val_accuracy: 0.7246 - lr: 1.0000e-04
# Epoch 6/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7762 - auc_roc: 0.5540 - auc_pr: 0.5363 - precision: 0.5277 - recall: 0.5748 - accuracy: 0.5302 - val_loss: 0.6823 - val_auc_roc: 0.4432 - val_auc_pr: 0.1264 - val_precision: 0.1194 - val_recall: 0.2222 - val_accuracy: 0.6314 - lr: 1.0000e-04
# Epoch 7/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7669 - auc_roc: 0.5705 - auc_pr: 0.5491 - precision: 0.5468 - recall: 0.5950 - accuracy: 0.5509 - val_loss: 0.6960 - val_auc_roc: 0.4441 - val_auc_pr: 0.1263 - val_precision: 0.1261 - val_recall: 0.3889 - val_accuracy: 0.4958 - lr: 1.0000e-04
# Epoch 8/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7459 - auc_roc: 0.5832 - auc_pr: 0.5602 - precision: 0.5525 - recall: 0.6025 - accuracy: 0.5572 - val_loss: 0.7093 - val_auc_roc: 0.4458 - val_auc_pr: 0.1274 - val_precision: 0.1528 - val_recall: 0.6111 - val_accuracy: 0.4237 - lr: 1.0000e-04
# Epoch 9/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7615 - auc_roc: 0.5788 - auc_pr: 0.5597 - precision: 0.5514 - recall: 0.5874 - accuracy: 0.5547 - val_loss: 0.7212 - val_auc_roc: 0.4492 - val_auc_pr: 0.1280 - val_precision: 0.1534 - val_recall: 0.7500 - val_accuracy: 0.3305 - lr: 1.0000e-04
# Epoch 10/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7591 - auc_roc: 0.5732 - auc_pr: 0.5553 - precision: 0.5521 - recall: 0.6000 - accuracy: 0.5566 - val_loss: 0.7326 - val_auc_roc: 0.4528 - val_auc_pr: 0.1293 - val_precision: 0.1487 - val_recall: 0.8056 - val_accuracy: 0.2669 - lr: 5.0000e-05
# Epoch 11/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7333 - auc_roc: 0.5936 - auc_pr: 0.5727 - precision: 0.5550 - recall: 0.6025 - accuracy: 0.5597 - val_loss: 0.7439 - val_auc_roc: 0.4571 - val_auc_pr: 0.1302 - val_precision: 0.1490 - val_recall: 0.8611 - val_accuracy: 0.2288 - lr: 5.0000e-05
# Epoch 12/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7561 - auc_roc: 0.5718 - auc_pr: 0.5615 - precision: 0.5487 - recall: 0.5887 - accuracy: 0.5522 - val_loss: 0.7558 - val_auc_roc: 0.4539 - val_auc_pr: 0.1292 - val_precision: 0.1521 - val_recall: 0.9167 - val_accuracy: 0.2076 - lr: 5.0000e-05
# Epoch 13/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7324 - auc_roc: 0.5917 - auc_pr: 0.5653 - precision: 0.5660 - recall: 0.6151 - accuracy: 0.5717 - val_loss: 0.7676 - val_auc_roc: 0.4569 - val_auc_pr: 0.1305 - val_precision: 0.1493 - val_recall: 0.9167 - val_accuracy: 0.1907 - lr: 5.0000e-05
# Epoch 14/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7269 - auc_roc: 0.6023 - auc_pr: 0.5745 - precision: 0.5672 - recall: 0.6214 - accuracy: 0.5736 - val_loss: 0.7790 - val_auc_roc: 0.4559 - val_auc_pr: 0.1304 - val_precision: 0.1518 - val_recall: 0.9444 - val_accuracy: 0.1864 - lr: 5.0000e-05
# Epoch 15/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7400 - auc_roc: 0.5882 - auc_pr: 0.5729 - precision: 0.5537 - recall: 0.5962 - accuracy: 0.5579 - val_loss: 0.7909 - val_auc_roc: 0.4556 - val_auc_pr: 0.1301 - val_precision: 0.1522 - val_recall: 0.9722 - val_accuracy: 0.1695 - lr: 5.0000e-05
# Epoch 16/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7243 - auc_roc: 0.5975 - auc_pr: 0.5765 - precision: 0.5533 - recall: 0.5811 - accuracy: 0.5560 - val_loss: 0.8023 - val_auc_roc: 0.4592 - val_auc_pr: 0.1310 - val_precision: 0.1522 - val_recall: 0.9722 - val_accuracy: 0.1695 - lr: 5.0000e-05
# Epoch 17/300
# 7/7 [==============================] - 0s 10ms/step - loss: 0.7435 - auc_roc: 0.5854 - auc_pr: 0.5508 - precision: 0.5472 - recall: 0.5836 - accuracy: 0.5503 - val_loss: 0.8140 - val_auc_roc: 0.4467 - val_auc_pr: 0.1281 - val_precision: 0.1509 - val_recall: 0.9722 - val_accuracy: 0.1610 - lr: 5.0000e-05
# Epoch 18/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7189 - auc_roc: 0.6076 - auc_pr: 0.5812 - precision: 0.5677 - recall: 0.6013 - accuracy: 0.5717 - val_loss: 0.8247 - val_auc_roc: 0.4490 - val_auc_pr: 0.1289 - val_precision: 0.1509 - val_recall: 0.9722 - val_accuracy: 0.1610 - lr: 2.5000e-05
# Epoch 19/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7270 - auc_roc: 0.6009 - auc_pr: 0.5774 - precision: 0.5669 - recall: 0.6025 - accuracy: 0.5711 - val_loss: 0.8351 - val_auc_roc: 0.4514 - val_auc_pr: 0.1293 - val_precision: 0.1509 - val_recall: 0.9722 - val_accuracy: 0.1610 - lr: 2.5000e-05
# Epoch 20/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7166 - auc_roc: 0.6143 - auc_pr: 0.6037 - precision: 0.5711 - recall: 0.6013 - accuracy: 0.5748 - val_loss: 0.8447 - val_auc_roc: 0.4469 - val_auc_pr: 0.1280 - val_precision: 0.1502 - val_recall: 0.9722 - val_accuracy: 0.1568 - lr: 2.5000e-05
# Epoch 21/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7227 - auc_roc: 0.6055 - auc_pr: 0.5875 - precision: 0.5696 - recall: 0.6126 - accuracy: 0.5748 - val_loss: 0.8544 - val_auc_roc: 0.4406 - val_auc_pr: 0.1265 - val_precision: 0.1502 - val_recall: 0.9722 - val_accuracy: 0.1568 - lr: 2.5000e-05

# %% [markdown]
# # 모델 학습과정 체크

# %%
import matplotlib.pyplot as plt

plt.rc('font', family = "Malgun Gothic")
plt.rcParams['axes.unicode_minus'] = False

fig, loss_ax = plt.subplots(figsize=(10,5))

loss_ax.plot(history.history.get('loss'), color='yellow',label='train loss')
loss_ax.plot(history.history.get('val_loss'), color='red',label='val loss')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc=(1.1,0.9))
acc_ax = loss_ax.twinx()
acc_ax.plot(history.history.get('accuracy'),color='green',label='train accuracy')
acc_ax.plot(history.history.get('val_accuracy'),color='blue',label='val binary accuracy')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc=(1.1,0.8))

# %% [markdown]
# # 모델평가

# %%
data = model.evaluate(X_te_s, y_te.astype(np.float32))
data
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6128 - auc_roc: 0.4972 - auc_pr: 0.1399 - precision: 0.0000e+00 - recall: 0.0000e+00 - accuracy: 0.8469
# [0.6127747893333435,
#  0.4971887469291687,
#  0.13985829055309296,
#  0.0,
#  0.0,
#  0.8469387888908386]

# %%
pred = model.predict(X_te_s).astype("int")
pd.crosstab(list(y_te), pred.ravel(), rownames=['실제값'],colnames=['예측값'])
# Out:
# 10/10 [==============================] - 0s 2ms/step
# 예측값    0
# 실제값
# 0    249
# 1     45

# %% [markdown]
# # oversampling도 크게 영향 없음
